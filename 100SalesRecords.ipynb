# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C://Users//user//.spyder-py3//100 Sales Records.csv')

# %%
columns = df.columns
print("The columns of the file 100 Sales Record are as follows : ", columns)
# Out:
# The columns of the file 100 Sales Record are as follows :  Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
df_10_x_10 = df.head(10)[['Region','Country','Item Type','Sales Channel','Order Priority','Order Date','Order ID','Ship Date','Units Sold', 'Unit Price']]
print(df_10_x_10)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub-Saharan Africa                 Angola        Household
# 7                 Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                 Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                 Sub-Saharan Africa                Senegal           Cereal
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# ...

# %%
plt.figure(1)
plt.xlabel('Records')
plt.ylabel('Total Profit')
plt.title('Total Profit of 100 Sales Record')
plt.plot(df['Total Profit'],marker='o')

# %%
Item_type_greater_than_1000000 = df[df['Total Cost']>1000000]['Item Type']
print(Item_type_greater_than_1000000)
# Out:
# 0           Baby Food
# 4     Office Supplies
# 6           Household
# 13          Household
# 16          Cosmetics
# 18          Household
# 19               Meat
# 20          Baby Food
# 29          Household
# 30          Cosmetics
# 32    Office Supplies
# 33          Household
# 37               Meat
# 38    Office Supplies
# 39    Office Supplies
# 41          Cosmetics
# 46          Cosmetics
# 53    Office Supplies
# 59          Cosmetics
# 62    Office Supplies
# 65          Cosmetics
# 68    Office Supplies
# 70    Office Supplies
# 73             Cereal
# 74          Cosmetics
# 75          Household
# 78          Baby Food
# 79          Cosmetics
# 80          Household
# 82          Cosmetics
# 92    Office Supplies
# 93          Cosmetics
# 99          Household
# Name: Item Type, dtype: object
